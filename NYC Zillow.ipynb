# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
zillow = pd.read_csv('/Users/ericlaibuffalo/CUSP/Data/Zillow/Zip_MedianValuePerSqft_AllHomes.csv')
zillow = zillow[zillow.City =='New York']

# %%
#zillow.to_csv('zillow_nyc.csv')
zillow_nyc = pd.read_csv('/Users/ericlaibuffalo/CUSP/Data/Zillow/zillow_nyc.csv')

# %%
zillow_nyc = zillow_nyc['RegionName',
# Out:
#      Unnamed: 0  RegionID  RegionName      City State     Metro CountyName  \
# 0             0     62080       11368  New York    NY  New York     Queens
# 1             4     62037       11226  New York    NY  New York      Kings
# 2             5     62093       11385  New York    NY  New York     Queens
# 3             6     62031       11220  New York    NY  New York      Kings
# 4             9     61639       10025  New York    NY  New York   New York
# 5            10     62044       11234  New York    NY  New York      Kings
# 6            12     62046       11236  New York    NY  New York      Kings
# 7            16     62019       11208  New York    NY  New York      Kings
# 8            17     62085       11373  New York    NY  New York     Queens
# 9            20     62018       11207  New York    NY  New York      Kings
# 10           25     62088       11377  New York    NY  New York     Queens
# ...
